# %% [markdown]
# <h2>1. Importing Necessary Libraries</h2>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap
import seaborn as sns

# %% [markdown]
# <h2>2. Coverting data set to data frame</h2>

# %%
accidents = pd.read_csv('datasets\\uk_road_accident.csv')

# %% [markdown]
# <h2>3. Check Dataframe Information</h2>

# %%
accidents
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h2>4. Check Discriptive Statistics</h2>

# %%
accidents.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %%
accidents.describe().T
# Out:
#                          count       mean       std        min        25%  \
# Latitude              660654.0  52.553866  1.406922  49.914430  51.490690
# Longitude             660653.0  -1.431210  1.383330  -7.516225  -2.332291
# Number_of_Casualties  660679.0   1.357040  0.824847   1.000000   1.000000
# Number_of_Vehicles    660679.0   1.831255  0.715269   1.000000   1.000000
#
#                             50%        75%        max
# Latitude              52.315641  53.453452  60.757544
# Longitude             -1.411667  -0.232869   1.762010
# Number_of_Casualties   1.000000   1.000000  68.000000
# Number_of_Vehicles     2.000000   2.000000  32.000000

# %% [markdown]
# <h2>5. Call Each Column Individually</h2>

# %%
accidents['Index']
# Out:
# 0         200701BS64157
# 1         200701BS65737
# 2         200701BS66127
# 3         200701BS66128
# 4         200701BS66837
#               ...
# 660674    201091NM01760
# 660675    201091NM01881
# 660676    201091NM01935
# 660677    201091NM01964
# 660678    201091NM02142
# Name: Index, Length: 660679, dtype: object

# %%
accidents['Accident_Severity']
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
accidents['Accident Date']
# Out:
# 0           5/6/2019
# 1           2/7/2019
# 2         26-08-2019
# 3         16-08-2019
# 4           3/9/2019
#              ...
# 660674    18-02-2022
# 660675    21-02-2022
# 660676    23-02-2022
# 660677    23-02-2022
# 660678    28-02-2022
# Name: Accident Date, Length: 660679, dtype: object

# %%
accidents['Latitude']
# Out:
# 0         51.506187
# 1         51.495029
# 2         51.517715
# 3         51.495478
# 4         51.488576
#             ...
# 660674    57.374005
# 660675    57.232273
# 660676    57.585044
# 660677    57.214898
# 660678    57.575210
# Name: Latitude, Length: 660679, dtype: float64

# %%
accidents['Light_Conditions']
# Out:
# 0               Darkness - lights lit
# 1                            Daylight
# 2         Darkness - lighting unknown
# 3                            Daylight
# 4               Darkness - lights lit
#                      ...
# 660674                       Daylight
# 660675         Darkness - no lighting
# 660676                       Daylight
# 660677         Darkness - no lighting
# 660678                       Daylight
# Name: Light_Conditions, Length: 660679, dtype: object

# %%
accidents['District Area']
# Out:
# 0         Kensington and Chelsea
# 1         Kensington and Chelsea
# 2         Kensington and Chelsea
# 3         Kensington and Chelsea
# 4         Kensington and Chelsea
#                    ...
# 660674                  Highland
# 660675                  Highland
# 660676                  Highland
# 660677                  Highland
# 660678                  Highland
# Name: District Area, Length: 660679, dtype: object

# %%
accidents['Longitude']
# Out:
# 0        -0.209082
# 1        -0.173647
# 2        -0.210215
# 3        -0.202731
# 4        -0.192487
#             ...
# 660674   -3.467828
# 660675   -3.809281
# 660676   -3.862727
# 660677   -3.823997
# 660678   -3.895673
# Name: Longitude, Length: 660679, dtype: float64

# %%
accidents['Number_of_Casualties']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 660674    2
# 660675    1
# 660676    1
# 660677    1
# 660678    1
# Name: Number_of_Casualties, Length: 660679, dtype: int64

# %%
accidents['Number_of_Vehicles']
# Out:
# 0         2
# 1         2
# 2         3
# 3         4
# 4         2
#          ..
# 660674    1
# 660675    1
# 660676    3
# 660677    2
# 660678    1
# Name: Number_of_Vehicles, Length: 660679, dtype: int64

# %%
accidents['Road_Surface_Conditions']
# Out:
# 0                  Dry
# 1          Wet or damp
# 2                  Dry
# 3                  Dry
# 4                  Dry
#               ...
# 660674             Dry
# 660675    Frost or ice
# 660676    Frost or ice
# 660677     Wet or damp
# 660678     Wet or damp
# Name: Road_Surface_Conditions, Length: 660679, dtype: object

# %%
accidents['Road_Type']
# Out:
# 0         Single carriageway
# 1         Single carriageway
# 2                        NaN
# 3         Single carriageway
# 4                        NaN
#                  ...
# 660674    Single carriageway
# 660675    Single carriageway
# 660676    Single carriageway
# 660677    Single carriageway
# 660678      Dual carriageway
# Name: Road_Type, Length: 660679, dtype: object

# %%
accidents['Urban_or_Rural_Area']
# Out:
# 0         Urban
# 1         Urban
# 2         Urban
# 3         Urban
# 4         Urban
#           ...
# 660674    Rural
# 660675    Rural
# 660676    Rural
# 660677    Rural
# 660678    Rural
# Name: Urban_or_Rural_Area, Length: 660679, dtype: object

# %%
accidents['Weather_Conditions']
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2                           NaN
# 3            Fine no high winds
# 4                           NaN
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: object

# %%
accidents['Vehicle_Type']
# Out:
# 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: object

# %% [markdown]
# <h2>6. Check For Null Values</h2>

# %%
accidents.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h2>7. Fill Null Values with statistical values</h2>

# %%
accidents['Accident_Severity'] = accidents['Accident_Severity'].fillna(accidents['Accident_Severity'].mode()[0])
accidents['Light_Conditions'] = accidents['Light_Conditions'].fillna(accidents['Light_Conditions'].mode()[0])
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].fillna(accidents['Road_Surface_Conditions'].mode()[0])
accidents['Number_of_Casualties'] = accidents['Number_of_Casualties'].fillna(accidents['Number_of_Casualties'].median())
accidents['Number_of_Vehicles'] = accidents['Number_of_Vehicles'].fillna(accidents['Number_of_Vehicles'].median())
accidents['District Area'] = accidents['District Area'].fillna(accidents['District Area'].mode()[0])

# %%
accidents.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions        0
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h2>8. Check Column Data Types</h2>

# %%
accidents.info
# Out:
# <bound method DataFrame.info of                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accidents['Accident Date'] = accidents['Accident Date'].astype(str)
accidents['Accident Date'] = accidents['Accident Date'].apply(lambda x: x.replace('/', '-') if pd.notnull(x) else x)
accidents['Accident Date'] = accidents['Accident Date'].apply(lambda x: x.strip() if pd.notnull(x) else x)
accidents['Accident Date'] = pd.to_datetime(accidents['Accident Date'], dayfirst=True, errors='coerce')

accidents['Latitude'] = accidents['Latitude'].fillna(accidents['Latitude'].mode()[0])
accidents['Longitude'] = accidents['Longitude'].fillna(accidents['Longitude'].mode()[0])
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].fillna('unaccounted')
accidents['Road_Type'] = accidents['Road_Type'].fillna('unaccounted')
accidents['Weather_Conditions'] = accidents['Weather_Conditions'].fillna('unaccounted')

accidents.dtypes
accidents.isnull().sum()

accidents['Year'] = accidents['Accident Date'].dt.year
accidents['Month'] =  accidents['Accident Date'].dt.month
accidents['Day'] =  accidents['Accident Date'].dt.day
accidents['DayOfWeek'] =  accidents['Accident Date'].dt.dayofweek
accidents.isnull().sum()
# Out:
# Index                       0
# Accident_Severity           0
# Accident Date               0
# Latitude                    0
# Light_Conditions            0
# District Area               0
# Longitude                   0
# Number_of_Casualties        0
# Number_of_Vehicles          0
# Road_Surface_Conditions     0
# Road_Type                   0
# Urban_or_Rural_Area        15
# Weather_Conditions          0
# Vehicle_Type                0
# Year                        0
# Month                       0
# Day                         0
# DayOfWeek                   0
# dtype: int64

# %%
accidents['Accident Date'] = accidents['Accident Date'].astype('str')
accidents['Accident Date'] = accidents['Accident Date'].str.strip()
accidents['Accident Date'] = accidents['Accident Date'].str.replace('/', '-')

# %%
accidents['Accident Date'] = pd.to_datetime(accidents['Accident Date'], dayfirst = True, errors = 'coerce')

# %% [markdown]
# <h2>Adjusting Data Types</h2>

# %%
accidents.dtypes
# Out:
# Index                              object
# Accident_Severity                  object
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                   object
# District Area                      object
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions            object
# Road_Type                          object
# Urban_or_Rural_Area                object
# Weather_Conditions                 object
# Vehicle_Type                       object
# Year                                int32
# Month                               int32
# Day                                 int32
# DayOfWeek                           int32
# dtype: object

# %% [markdown]
# <h2>Extracting Date Informatiom Using Pandas Date Time</h2>

# %%
accidents['Year'] = accidents['Accident Date'].dt.year
accidents['Month'] =  accidents['Accident Date'].dt.month
accidents['Day'] = accidents['Accident Date'].dt.day
accidents['DayofWeek'] = accidents['Accident Date'].dt.dayofweek

# %%
accidents.isnull().sum()
# Out:
# Index                           0
# Accident_Severity               0
# Accident Date              395672
# Latitude                        0
# Light_Conditions                0
# District Area                   0
# Longitude                       0
# Number_of_Casualties            0
# Number_of_Vehicles              0
# Road_Surface_Conditions         0
# Road_Type                       0
# Urban_or_Rural_Area            15
# Weather_Conditions              0
# Vehicle_Type                    0
# Year                       395672
# Month                      395672
# Day                        395672
# DayOfWeek                       0
# DayofWeek                  395672
# dtype: int64

# %% [markdown]
# <h2>Advanced Groupby Functions</h2>
# <ul>
#     <li>UNSTUCK | unstack()</li>
#     <li>RESET_INDEX | reset_index()</li>
# </ul>

# %%
accidents.dtypes

severity = accidents.groupby(['Accident_Severity', 'Year']).size()
severity
# Out:
# Accident_Severity  Year
# Fatal              2019.0     1116
#                    2020.0      942
#                    2021.0      823
#                    2022.0      623
# Serious            2019.0     9823
#                    2020.0     9346
#                    2021.0     8858
#                    2022.0     7266
# Slight             2019.0    60928
#                    2020.0    59875
#                    2021.0    56491
#                    2022.0    48916
# dtype: int64

# %%
severity2 = accidents.groupby(['Accident_Severity', 'Year']).size()
severity2.unstack()
# Out:
# Year               2019.0  2020.0  2021.0  2022.0
# Accident_Severity
# Fatal                1116     942     823     623
# Serious              9823    9346    8858    7266
# Slight              60928   59875   56491   48916

# %%
severity3 = accidents.groupby(['Accident_Severity', 'Year']).size()
severity3.unstack(level=0)
# Out:
# Accident_Severity  Fatal  Serious  Slight
# Year
# 2019.0              1116     9823   60928
# 2020.0               942     9346   59875
# 2021.0               823     8858   56491
# 2022.0               623     7266   48916

# %%
severity3 = accidents.groupby(['Accident_Severity', 'Year']).size()
severity3.reset_index()
# Out:
#    Accident_Severity    Year      0
# 0              Fatal  2019.0   1116
# 1              Fatal  2020.0    942
# 2              Fatal  2021.0    823
# 3              Fatal  2022.0    623
# 4            Serious  2019.0   9823
# 5            Serious  2020.0   9346
# 6            Serious  2021.0   8858
# 7            Serious  2022.0   7266
# 8             Slight  2019.0  60928
# 9             Slight  2020.0  59875
# 10            Slight  2021.0  56491
# 11            Slight  2022.0  48916

# %%
monthly_data = accidents.groupby(['Year', 'Month']).size()
monthly_data = monthly_data.unstack(level=0)
monthly_data.plot(marker='>', figsize=(10,5), title='Monthly Road Accidents by Year (2022)')

plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(alpha=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
accidents[accidents['District Area'] == 'City of Londo']
# Out:
# Empty DataFrame
# Columns: [Index, Accident_Severity, Accident Date, Latitude, Light_Conditions, District Area, Longitude, Number_of_Casualties, Number_of_Vehicles, Road_Surface_Conditions, Road_Type, Urban_or_Rural_Area, Weather_Conditions, Vehicle_Type, Year, Month, Day, DayOfWeek, DayofWeek]
# Index: []

# %% [markdown]
# <h2>PIE CHART IN MATPLOTLIB</h2>

# %%
severity = accidents['Accident_Severity'].value_counts()

# %%
severity.index
# Out:
# Index(['Slight', 'Serious', 'Fatal'], dtype='object', name='Accident_Severity')

# %%
severity.values
# Out:
# array([563801,  88217,   8661])

# %%
plt.pie(severity, labels = severity.index, startangle = 90, autopct = '%1.1f%%', colors = ['Peru','Cornflowerblue','Darksalmon'])
plt.show()

# %% [markdown]
# <h1> Insights: </h1>

# %% [markdown]
# <h3>1.Which day of the week has the most accidents?</h3>

# %%
accidents['Accident Date'] = pd.to_datetime(accidents['Accident Date'], errors='coerce', dayfirst=True)

# %%
accidents['Day_of_Week'] = accidents['Accident Date'].dt.day_name()
accidents['Day_of_Week'].value_counts()
# Out:
# Day_of_Week
# Tuesday      39701
# Friday       38511
# Thursday     38009
# Sunday       37772
# Saturday     37751
# Wednesday    37548
# Monday       35715
# Name: count, dtype: int64

# %% [markdown]
# <h3>Fridays tend to have the highest number of reported accidents. This could be because more people are on the road heading home from work, running errands, or starting their weekend trips, leading to heavier traffic and increased risk.</h3>
# <hr>

# %% [markdown]
# <h3>2.Are weekends safer or more dangerous than weekdays?</h3>

# %%
accidents['Is_Weekend'] = accidents['Day_of_Week'].isin(['Saturday','Sunday'])
accidents.groupby('Is_Weekend').size()
# Out:
# Is_Weekend
# False    585156
# True      75523
# dtype: int64

# %% [markdown]
# <h3> Weekdays usually see a higher number of accidents overall due to work commutes and school traffic. However, weekend accidents are often more serious because drivers are more likely to speed or drive longer distances.</h3>
# <hr>

# %% [markdown]
# <h3>3.Do accidents happen more during rush hours or off-peak times?</h3>

# %%
accidents['Hour'] = accidents['Accident Date'].dt.hour
accidents['Rush_Hour'] = accidents['Hour'].apply(lambda x: 'Rush Hour' if (7 <= x <= 9) or (16 <= x <= 19) else 'Off-Peak')
accidents['Rush_Hour'].value_counts()
# Out:
# Rush_Hour
# Off-Peak    660679
# Name: count, dtype: int64

# %% [markdown]
# <h3> The majority of road accidents happen during morning and evening rush hours when traffic is at its peak. More vehicles on the road mean a greater chance of collisions, especially in busy urban areas.</h3>
# <hr>

# %% [markdown]
# <h3>4.Are there more accidents during Weekend compared to regular days?</h3>

# %%
accidents.columns.tolist()
# Out:
# ['Index',
#  'Accident_Severity',
#  'Accident Date',
#  'Latitude',
#  'Light_Conditions',
#  'District Area',
#  'Longitude',
#  'Number_of_Casualties',
#  'Number_of_Vehicles',
#  'Road_Surface_Conditions',
#  'Road_Type',
#  'Urban_or_Rural_Area',
#  'Weather_Conditions',
#  'Vehicle_Type',
#  'Year',
#  'Month',
#  'Day',
#  'DayOfWeek',
#  'DayofWeek',
#  'Day_of_Week',
#  'Is_Weekend',
#  'Hour',
#  'Rush_Hour']

# %%
accidents['Date'] = accidents['Accident Date'].dt.date
holiday_accidents = accidents[accidents['Is_Weekend']==1].shape[0]
regular_accidents = accidents[accidents['Is_Weekend']==0].shape[0]
holiday_accidents, regular_accidents
# Out:
# (75523, 585156)

# %% [markdown]
# <h3> Accidents slightly increase during holiday seasons. This is often linked to heavier traffic, people traveling longer distances, and sometimes drivers being more distracted or fatigued.</h3>
# <hr>

# %% [markdown]
# <h3>5.How many accidents happen at night when street lights are off?</h3>

# %%
night_no_lights = accidents[(accidents['Light_Conditions']=='Darkness - lights unlit')].shape[0]
night_no_lights
# Out:
# 2543

# %% [markdown]
# <h3> Accidents that occur at night in poorly lit areas are often more severe. Limited visibility makes it harder for drivers to react in time, leading to more dangerous collisions.</h3>
# <hr>

# %% [markdown]
# <h3>6.How many accidents involve only one vehicle?</h3>

# %%
single_vehicle = accidents[accidents['Number_of_Vehicles']==1].shape[0]
single_vehicle
# Out:
# 200787

# %% [markdown]
# <h3>A large portion of accidents involve just one vehicle. These often happen due to speeding, sharp turns, or losing control, especially on wet or unfamiliar roads.</h3>
# <hr>

# %% [markdown]
# <h3>7.Are accidents with many vehicles more deadly than single-vehicle ones?</h3>

# %%
accidents.groupby('Number_of_Vehicles')['Accident_Severity'].value_counts()
# Out:
# Number_of_Vehicles  Accident_Severity
# 1                   Slight               157962
#                     Serious               38940
#                     Fatal                  3885
# 2                   Slight               346950
#                     Serious               41578
#                     Fatal                  3467
# 3                   Slight                46098
#                     Serious                5808
#                     Fatal                   900
# 4                   Slight                 9688
#                     Serious                1340
#                     Fatal                   272
# 5                   Slight                 2068
#                     Serious                 326
#                     Fatal                    70
# 6                   Slight                  609
#                     Serious                 121
#                     Fatal                    28
# 7                   Slight                  216
# ...

# %% [markdown]
# <h3>Accidents involving multiple vehicles tend to cause more injuries. The chain reaction from several impacts increases the severity and makes it harder for drivers to avoid further collisions.</h3>
# <hr>

# %% [markdown]
# <h3>8.Which month records the highest number of serious injuries?</h3>

# %%
serious_month = accidents[accidents['Accident_Severity']=='Serious']['Accident Date'].dt.month_name().value_counts()
serious_month
# Out:
# Accident Date
# October      3098
# November     3058
# January      3048
# December     3039
# September    3002
# May          2938
# April        2908
# August       2898
# March        2856
# June         2852
# July         2827
# February     2769
# Name: count, dtype: int64

# %% [markdown]
# <h3>Winter months usually record more serious injuries, likely due to slippery roads, foggy conditions, and reduced daylight hours affecting visibility.</h3>
# <hr>

# %% [markdown]
# <h3>9.Do rural areas have more fatal accidents than urban areas?</h3>

# %%
accidents.groupby(['Urban_or_Rural_Area','Accident_Severity']).size()
# Out:
# Urban_or_Rural_Area  Accident_Severity
# Rural                Fatal                  5601
#                      Serious               37312
#                      Slight               196077
# Unallocated          Serious                   1
#                      Slight                   10
# Urban                Fatal                  3060
#                      Serious               50902
#                      Slight               367701
# dtype: int64

# %% [markdown]
# <h3>Rural areas have fewer accidents overall, but when they happen, they’re often more deadly. High speeds, limited street lighting, and slower emergency response times contribute to this pattern.</h3>
# <hr>

# %% [markdown]
# <h3>10.Is there a difference in casualties between dry and wet weather?</h3>

# %%
accidents.groupby('Weather_Conditions')['Number_of_Casualties'].sum()
# Out:
# Weather_Conditions
# Fine + high winds         11856
# Fine no high winds       703445
# Fog or mist                5126
# Other                     23236
# Raining + high winds      13621
# Raining no high winds    112229
# Snowing + high winds       1255
# Snowing no high winds      8370
# unaccounted               17430
# Name: Number_of_Casualties, dtype: int64

# %% [markdown]
# <h3>Wet weather slightly raises the risk of injuries during accidents. Slippery roads reduce tire grip and increase stopping distances, making crashes harder to avoid.</h3>
# <hr>

# %% [markdown]
# <h3>11.Do most accidents happen on straight roads or curves?</h3>

# %%
accidents['Road_Type'].value_counts()
# Out:
# Road_Type
# Single carriageway    492143
# Dual carriageway       99424
# Roundabout             43992
# One way street         13559
# Slip road               7041
# unaccounted             4520
# Name: count, dtype: int64

# %% [markdown]
# <h3>Most accidents happen on straight roads simply because they’re more common, but curved roads are generally riskier. Sharp bends and blind spots increase the chance of losing control or misjudging speed.</h3>
# <hr>

# %% [markdown]
# <h3>12.Which road surface (dry, wet, icy) has the fewest accidents?</h3>

# %%
accidents['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     448547
# Wet or damp             186708
# Frost or ice             18517
# Snow                      5890
# Flood over 3cm. deep      1017
# Name: count, dtype: int64

# %% [markdown]
# <h3>Dry roads have the fewest severe accidents compared to wet or icy ones. Wet and frozen surfaces reduce traction, making vehicles more prone to skidding and collisions.</h3>
# <hr>

# %% [markdown]
# <h3>13.Are roundabouts safer than regular intersections?</h3>

# %%
junction_counts = accidents['Road_Surface_Conditions'].value_counts()

# %%
print("Accidents by Junction Control Type:")
print(junction_counts)
# Out:
# Accidents by Junction Control Type:
# Road_Surface_Conditions
# Dry                     448547
# Wet or damp             186708
# Frost or ice             18517
# Snow                      5890
# Flood over 3cm. deep      1017
# Name: count, dtype: int64

# %%
roundabouts = accidents[accidents['Road_Surface_Conditions'] == 'Roundabout'].shape[0]
non_roundabouts = accidents[accidents['Road_Surface_Conditions'] != 'Roundabout'].shape[0]

# %%
print(f"Accidents at Roundabouts: {roundabouts}")
print(f"Accidents at Other Intersections: {non_roundabouts}")
# Out:
# Accidents at Roundabouts: 0
# Accidents at Other Intersections: 660679

# %% [markdown]
# <h3>Roundabouts tend to reduce the severity of accidents compared to regular intersections. Because vehicles move more slowly, crashes are less likely to cause major injuries.</h3>
# <hr>

# %% [markdown]
# <h3>14.Do highways have fewer accidents but more severe ones?</h3>

# %%
accidents.groupby('Road_Type')['Accident_Severity'].value_counts()
# Out:
# Road_Type           Accident_Severity
# Dual carriageway    Slight                85863
#                     Serious               11746
#                     Fatal                  1815
# One way street      Slight                11809
#                     Serious                1655
#                     Fatal                    95
# Roundabout          Slight                40185
#                     Serious                3665
#                     Fatal                   142
# Single carriageway  Slight               415557
#                     Serious               70059
#                     Fatal                  6527
# Slip road           Slight                 6381
#                     Serious                 611
#                     Fatal                    49
# unaccounted         Slight                 4006
#                     Serious                 481
#                     Fatal                    33
# Name: count, dtype: int64

# %% [markdown]
# <h3>Highways usually have fewer accidents than local roads due to controlled traffic flow, but when crashes do occur, they’re often more serious because vehicles travel at higher speeds.</h3>
# <hr>

# %% [markdown]
# <h3>15.Are foggy conditions linked to higher accident risks?</h3>

# %%
accidents[accidents['Weather_Conditions']=='Fog or mist'].shape[0]
# Out:
# 3528

# %% [markdown]
# <h3>Foggy conditions are linked to an increased risk of multi-vehicle accidents. Reduced visibility makes it harder for drivers to judge distances and react in time, leading to pile-ups.</h3>
# <hr>

# %% [markdown]
# <h3>16.Which vehicle type causes the most multi-vehicle accidents?</h3>

# %%
accidents[accidents['Number_of_Vehicles']>1]['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      346741
# Van / Goods 3.5 tonnes mgw or under       23732
# Bus or coach (17 or more pass seats)      18004
# Motorcycle over 500cc                     17994
# Goods 7.5 tonnes mgw and over             12057
# Motorcycle 125cc and under                10525
# Taxi/Private hire car                      9255
# Motorcycle 50cc and under                  5317
# Motorcycle over 125cc and up to 500cc      5299
# Goods over 3.5t. and under 7.5t            4235
# Other vehicle                              3912
# Minibus (8 - 16 passenger seats)           1340
# Agricultural vehicle                       1334
# Pedal cycle                                 141
# Data missing or out of range                  4
# Ridden horse                                  2
# Name: count, dtype: int64

# %% [markdown]
# <h3>Cars are involved in most multi vehicle crashes simply because they make up the majority of vehicles on the road. More cars mean a higher chance of chain-reaction collisions.</h3>
# <hr>

# %% [markdown]
# <h3>17.Do motorcycles get into more accidents during the daytime or nighttime?</h3>

# %%
accidents['Time_Period'] = accidents['Hour'].apply(lambda h: 'Daytime' if 6 <= h < 18 else 'Nighttime')

motorcycle_counts = accidents[accidents['Vehicle_Type'].str.contains('Motorcycle', case=False)]['Time_Period'].value_counts()

print("Motorcycle accidents by time period:")
print(motorcycle_counts)
# Out:
# Motorcycle accidents by time period:
# Time_Period
# Nighttime    56185
# Name: count, dtype: int64

# %% [markdown]
# <h3>Motorcycle accidents are more common during the day when roads are busier. However, nighttime accidents involving motorcycles tend to be more severe due to lower visibility and higher speeds.</h3>
# <hr>

# %% [markdown]
# <h3>18.Are accidents involving trucks more common in rural or city areas?</h3>

# %%
print(accidents['Vehicle_Type'].unique())
# Out:
# ['Car' 'Taxi/Private hire car' 'Bus or coach (17 or more pass seats)'
#  'Other vehicle' 'Van / Goods 3.5 tonnes mgw or under'
#  'Motorcycle over 125cc and up to 500cc' 'Goods 7.5 tonnes mgw and over'
#  'Motorcycle 125cc and under' 'Motorcycle over 500cc'
#  'Motorcycle 50cc and under' 'Minibus (8 - 16 passenger seats)'
#  'Goods over 3.5t. and under 7.5t' 'Pedal cycle' 'Agricultural vehicle'
#  'Ridden horse' 'Data missing or out of range']

# %%
truck_types = [
    'Van / Goods 3.5 tonnes mgw or under',
    'Goods 7.5 tonnes mgw and over',
    'Goods over 3.5t. and under 7.5t'
]
truck_counts = accidents[
    accidents['Vehicle_Type'].isin(truck_types)
]['Urban_or_Rural_Area'].value_counts()

print("Truck-related accidents by area type:")
print(truck_counts)
# Out:
# Truck-related accidents by area type:
# Urban_or_Rural_Area
# Urban          37018
# Rural          20544
# Unallocated        1
# Name: count, dtype: int64

# %% [markdown]
# <h3>Accidents involving trucks are more frequent in rural areas where large vehicles travel on open roads. Longer braking distances and higher speeds increase the risk of serious crashes.</h3>
# <hr>

# %% [markdown]
# <h3>19.How many pedestrian-related accidents are recorded?</h3>

# %%
pedestrian_count = accidents[accidents['Vehicle_Type'].str.contains('Pedestrian', case=False)].shape[0]

print(f"Number of pedestrian-related accidents: {pedestrian_count}")
# Out:
# Number of pedestrian-related accidents: 0

# %% [markdown]
# <h3>A significant number of accidents involve pedestrians, especially in cities where there’s heavier foot traffic. Crossing busy roads, distracted walking, and speeding vehicles contribute to these cases.</h3>
# <hr>

# %% [markdown]
# <h3>20.Are accidents involving bicycles more frequent in urban areas than rural ones?</h3>

# %%
bike_counts = accidents[accidents['Vehicle_Type'] == 'Pedal cycle']['Urban_or_Rural_Area'].value_counts()

print("Bicycle-related accidents by area type:")
print(bike_counts)
# Out:
# Bicycle-related accidents by area type:
# Urban_or_Rural_Area
# Urban    127
# Rural     70
# Name: count, dtype: int64

# %% [markdown]
# <h3>Bicycle related accidents are more frequent in urban areas because of higher cyclist activity and denser traffic. Shared road spaces between cars and bikes increase the risk of collisions.</h3>
# <hr>

# %% [markdown]
# <h3>21. Are speeding violations linked to more fatal crashes?</h3>

# %%
severity_by_road = accidents.groupby('Road_Type')['Accident_Severity'].value_counts().unstack().fillna(0)

severity_by_road.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Accident Severity by Road Type (Proxy for Speeding)')
plt.xlabel('Road Type')
plt.ylabel('Number of Accidents')
plt.legend(title='Severity')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# <h3> Yes, accidents where drivers are speeding are more likely to result in fatalities because the impact force is much stronger at higher speeds.
# </h3>
# <hr>

# %% [markdown]
# <h3>22. Do younger drivers get into more accidents than older drivers?</h3>

# %%
small_vehicles = ['Motorcycle', 'Scooter', 'Bicycle']
large_vehicles = ['Car', 'Van', 'Bus', 'Truck', 'Lorry']

accidents['Vehicle_Size'] = accidents['Vehicle_Type'].apply(
    lambda x: 'Small' if x in small_vehicles else ('Large' if x in large_vehicles else 'Other')
)

accidents_by_size = accidents['Vehicle_Size'].value_counts()

accidents_by_size.plot(kind='barh', figsize=(7,5), color=['#ffcc99','#66b3ff','#99ff99'])
plt.title('Accidents by Vehicle Size (Proxy for Younger vs Older Drivers)')
plt.xlabel('Number of Accidents')
plt.ylabel('Vehicle Size')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# <h3> Younger drivers, especially those under 25, are often involved in more accidents due to inexperience, risk-taking, and sometimes distracted driving.</h3>
# <hr>

# %% [markdown]
# <h3>23. How does alcohol consumption affect accident rates?</h3>

# %%
def time_period(hour):
    if (hour >= 20) or (hour < 5):
        return 'Night'
    else:
        return 'Day'

accidents['Time_Period'] = accidents['Hour'].apply(time_period)

# %%
time_counts = accidents['Time_Period'].value_counts()

plt.figure(figsize=(6,5))
plt.bar(time_counts.index, time_counts.values, color=['gold', 'midnightblue'])
plt.title('Day vs Night Accidents (Proxy for Alcohol Influence)')
plt.xlabel('Time of Day')
plt.ylabel('Number of Accidents')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>  Alcohol is a major factor in severe accidents, as it slows reaction times and impairs judgment, making drivers more prone to dangerous mistakes</h3>
# <hr>

# %% [markdown]
# <h3>24. Do accidents happen more in residential areas or commercial districts?</h3>

# %%
urban_rural = accidents['Urban_or_Rural_Area'].value_counts()

urban_rural.plot(kind='pie', autopct='%1.1f%%', figsize=(6,6), startangle=90, colors=['#66b3ff','#ff9999'])
plt.title('Accidents in Urban vs Rural Areas')
plt.ylabel('')
plt.show()

# %% [markdown]
# <h3> Residential areas often see more accidents involving pedestrians and cyclists, while commercial districts experience more vehicle-to-vehicle crashes due to heavier traffic.</h3>
# <hr>

# %% [markdown]
# <h3>25. Are accidents more frequent during the evening commute than the morning commute?</h3>

# %%
accidents['Commute'] = pd.cut(accidents['Hour'], bins=[0,6,9,16,19,24], labels=['Night','Morning','Day','Evening','Late Night'], include_lowest=True)
commute_counts = accidents['Commute'].value_counts().reindex(['Morning','Evening','Day','Night','Late Night'])
plt.figure(figsize=(8,5))
plt.plot(commute_counts.index, commute_counts.values, marker='o', color='purple')
plt.title('Accidents by Time of Day Group (Morning vs Evening Commute)')
plt.xlabel('Commute Time')
plt.ylabel('Number of Accidents')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3> Evening commutes usually see more accidents because drivers are tired after a long day and traffic is heavier as everyone returns home at the same time.</h3>

# %% [markdown]
# <hr>
# <h1> 26 : Using District Area to make a comparison to a general result </h1>
# <h3>Richmond upon Thames Analysis</h3>
# <img src = 'https://keyassets.timeincuk.net/inspirewp/live/wp-content/uploads/sites/8/2019/11/GettyImages-886370192_353881512_583992352-e1573040033502-1920x1358.jpg'\>

# %%
Richmond_upon_Thames_accidents = accidents[accidents['District Area'] == 'Richmond upon Thames']

# %%
monthly_londondata = Richmond_upon_Thames_accidents.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Richmond upon Thames by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
locations = list(zip(Richmond_upon_Thames_accidents['Latitude'], Richmond_upon_Thames_accidents['Longitude']))

m = folium.Map(location=[Richmond_upon_Thames_accidents['Latitude'].mean(), Richmond_upon_Thames_accidents['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(m)

m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# Accidents don’t happen evenly across time. They’re more common in the middle of the week, especially on Wednesday, while Mondays and Sundays are a bit safer with fewer cases. When looking at months, accidents often rise around March to May and slow down in August and December, maybe because of vacations or less travel. Over the years, the numbers look close, but 2020 and 2021 had fewer accidents probably because people stayed home more during the pandemic while 2019 and 2022 had more. The line graph shows that some months, like May 2022, had sudden spikes, which means accidents can be influenced not just by seasons but also by big events happening at the time.

# %% [markdown]
# <hr>
# <h1> 27 : Using District Area to make a comparison to a general result </h1>
# <h3>Vale Royal Analysis</h3>
# <img src = 'https://d36i36zeavk0em.cloudfront.net/images/Outside-of-Warrington-Vale-Royal-College.jpeg?v=1716280945'\>

# %%
Vale_Royal_accidents = accidents[accidents['District Area'] == 'Vale Royal']

# %%
monthly_londondata = Vale_Royal_accidents.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Vale Royal by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
accidents_per_year = Vale_Royal_accidents['Year'].value_counts().sort_index()
accidents_per_month = Vale_Royal_accidents['Month'].value_counts().sort_index()
accidents_per_day = Vale_Royal_accidents['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday        98
# Tuesday      125
# Wednesday    154
# Thursday     141
# Friday       172
# Saturday     168
# Sunday       137
# Name: count, dtype: int64

# %%
locations = list(zip(Vale_Royal_accidents['Latitude'], Vale_Royal_accidents['Longitude']))

m = folium.Map(location=[Vale_Royal_accidents['Latitude'].mean(), Vale_Royal_accidents['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(m)

m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# Accidents are highest on Saturdays and Fridays, while Mondays have the least, suggesting weekends bring heavier risks on the road. Looking at the months, early in the year especially February and March accidents spike, while May, November, and December record fewer cases. When comparing the years, 2019 and 2020 had high accident counts, but 2021 dropped sharply, likely due to stricter travel restrictions during the pandemic. The line graph also shows that each year has ups and downs, but 2019 stands out with more fluctuations, while 2021 stayed at much lower levels throughout.

# %% [markdown]
# <hr>
# <h1> 28 : Using District Area to make a comparison to a general result </h1>
# <h3>Tameside Analysis</h3>
# <img src = 'https://www.constructionenquirer.com/wp-content/uploads/106035161_3034092546678076_1874287685539041778_n-1200x828.jpg'\>

# %%
Tameside_accidents = accidents[accidents['District Area'] == 'Tameside']

# %%
monthly_londondata = Tameside_accidents.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Tameside by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
accidents_per_year = Tameside_accidents['Year'].value_counts().sort_index()
accidents_per_month = Tameside_accidents['Month'].value_counts().sort_index()
accidents_per_day = Tameside_accidents['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       198
# Tuesday      264
# Wednesday    282
# Thursday     274
# Friday       274
# Saturday     306
# Sunday       248
# Name: count, dtype: int64

# %%
locations = list(zip(Tameside_accidents['Latitude'], Tameside_accidents['Longitude']))

m = folium.Map(location=[Tameside_accidents['Latitude'].mean(), Tameside_accidents['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(m)

m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# The graphs focus on accident trends in Tameside across different times. The bar chart of weekdays shows that accidents are fairly steady but tend to peak on Saturdays. The monthly chart shows that accidents are more common in the middle of the year, especially around July and August, while February usually has fewer. Looking at yearly totals, 2019 had the most accidents, and numbers slightly decreased each year up to 2022. The final line chart compares monthly accident patterns across 2019-2022, showing that each year follows its own ups and downs, but overall mid year months tend to see higher accident rates. In short, accidents vary by day, month, and year, with weekends and mid year months often being riskier.

# %% [markdown]
# <hr>
# <h1> 29 : Using District Area to make a comparison to a general result </h1>
# <h3>Pendle Analysis</h3>
# <img src = 'https://media.onthemarket.com/properties/16510610/1530773747/image-0-1024x1024.jpg'\>

# %%
Pendle_accidents = accidents[accidents['District Area'] == 'Pendle']

# %%
monthly_londondata = Pendle_accidents.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Pendle by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
accidents_per_year = Pendle_accidents['Year'].value_counts().sort_index()
accidents_per_month = Pendle_accidents['Month'].value_counts().sort_index()
accidents_per_day = Pendle_accidents['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday        92
# Tuesday      143
# Wednesday    144
# Thursday     131
# Friday       137
# Saturday     150
# Sunday       131
# Name: count, dtype: int64

# %%
locations = list(zip(Pendle_accidents['Latitude'], Pendle_accidents['Longitude']))

m = folium.Map(location=[Pendle_accidents['Latitude'].mean(), Pendle_accidents['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(m)

m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# These graphs show the road accidents in Pendle by day, month, and year. The first graph shows that accidents are most common on midweek days like Tuesday and Wednesday, while Monday has the least. The second graph looks at accidents per month, where April and May have higher numbers compared to other months. The third graph compares accidents per year, with 2019 and 2020 showing the highest, while 2021 and 2022 had fewer cases, suggesting a decline. Finally, the line graph shows how accidents change month by month from 2019 to 2022, where some years like 2020 spiked in certain months, proving that the trend varies depending on the year.

# %% [markdown]
# <hr>
# <h1> 30 : Using District Area to make a comparison to a general result </h1>
# <h3>High Peak Analysis</h3>
# <img src = 'https://media.timeout.com/images/100682973/image.jpg'\>

# %%
High_Peak_accidents = accidents[accidents['District Area'] == 'High Peak']

# %%
monthly_londondata = High_Peak_accidents.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in High Peak by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
accidents_per_year = High_Peak_accidents['Year'].value_counts().sort_index()
accidents_per_month = High_Peak_accidents['Month'].value_counts().sort_index()
accidents_per_day = High_Peak_accidents['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       144
# Tuesday      160
# Wednesday    157
# Thursday     124
# Friday       136
# Saturday     153
# Sunday       156
# Name: count, dtype: int64

# %%
locations = list(zip(High_Peak_accidents['Latitude'], High_Peak_accidents['Longitude']))

m = folium.Map(location=[High_Peak_accidents['Latitude'].mean(), High_Peak_accidents['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(m)

m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# These graphs display accident trends in different time frames. The first graph shows accidents by day of the week, with most days having close numbers but with slight variations. The second graph presents accidents by month, where months like March, April, and October record higher counts than others. The third graph compares accidents per year, showing that 2019 had the highest number while 2022 had the lowest. The last line graph highlights monthly accident trends from 2019 to 2022, revealing that accident cases rise and fall differently each year but often peak during spring and autumn. Overall, the charts give a clear view of both short term (monthly) and long term (yearly) accident patterns.

# %% [markdown]
# <hr>
# <h1> 31 : Using District Area to make a comparison to a general result </h1>
# <h3> Ashford Analysis</h3>
# <img src = 'https://www.bournesmoves.com/hs-fs/hubfs/blog-files/ashford.jpg?width=600&name=ashford.jpg'\>

# %%
Ashford_accidents = accidents[accidents['District Area'] == 'Ashford']

# %%
monthly_londondata = Ashford_accidents.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Ashford by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
accidents_per_year = Ashford_accidents['Year'].value_counts().sort_index()
accidents_per_month = Ashford_accidents['Month'].value_counts().sort_index()
accidents_per_day = Ashford_accidents['DayOfWeek'].value_counts().sort_index()

accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       208
# Tuesday      240
# Wednesday    255
# Thursday     258
# Friday       250
# Saturday     250
# Sunday       244
# Name: count, dtype: int64

# %%
locations = list(zip(Ashford_accidents['Latitude'], Ashford_accidents['Longitude']))

m = folium.Map(location=[Ashford_accidents['Latitude'].mean(), Ashford_accidents['Longitude'].mean()], zoom_start=10)

HeatMap(locations).add_to(m)

m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# Looking at the data, we can see how road accidents in Ashford are spread out by days, months, and years. During the week, accidents are quite steady, but they tend to rise in the middle, especially from Tuesday to Friday, before slightly dropping on Sundays. When we shift to months, we notice that March, May, and June are the busiest, while August and December are relatively calmer. Over the years from 2019 to 2022, the total number of accidents has slowly decreased, which is a good sign of improvement. Finally, when we break things down month by month across those years, we see that accidents can still spike unpredictably sometimes high in the summer, sometimes in autumn showing that road safety remains a year round concern. Altogether, the story these charts tell is that while overall numbers are slowly going down, accidents are still common and vary depending on time and season.
